# %% [markdown]
# <a href="https://colab.research.google.com/github/tutalae/AI02HERO/blob/main/voice_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pythaiasr

# %%
from pythaiasr import asr
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52e2767d-543e-4219-9251-d589cb3db39d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52e2767d-543e-4219-9251-d589cb3db39d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-21dc3c638f66> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
file = "a.wav"

# %%
print(asr(file))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-c0b81009d1b7> in <module>()
# ----> 1 print(asr(file))
#
# /usr/local/lib/python3.7/dist-packages/pythaiasr/__init__.py in asr(file, tokenized)
#      40     b = {}
#      41     b['path'] = file
# ---> 42     a = prepare_dataset(resample(speech_file_to_array_fn(b)))
#      43     input_dict = processor(a["input_values"][0], return_tensors="pt", padding=True)
#      44     logits = model(input_dict.input_values.to(device)).logits
#
# /usr/local/lib/python3.7/dist-packages/pythaiasr/__init__.py in speech_file_to_array_fn(batch)
#      12
#      13 def speech_file_to_array_fn(batch: dict) -> dict:
# ---> 14     speech_array, sampling_rate = torchaudio.load(batch["path"])
#      15     batch["speech"] = speech_array[0]
#      16     batch["sampling_rate"] = sampling_rate
#
# ...
